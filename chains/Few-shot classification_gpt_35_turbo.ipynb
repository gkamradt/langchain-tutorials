# %%
from langchain.prompts.example_selector import SemanticSimilarityExampleSelector
from langchain.vectorstores import FAISS
from langchain.embeddings import OpenAIEmbeddings
from langchain.prompts import FewShotPromptTemplate, PromptTemplate
from langchain.llms import OpenAI
import pandas as pd
from dotenv import load_dotenv
import openai
import os

# %%
from dotenv import load_dotenv  
import os  
import openai
import os  
  

# Configure OpenAI API

AZURE_OPENAI_API_VERSION = "2023-03-15-preview"
AZURE_OPENAI_ENDPOINT ="https://cog-42as6n6i4ldsi.openai.azure.com/"
AZURE_OPENAI_API_KEY ="653103af9cd04492a2232b70327b7ce0"

# Set the ENV variables that Langchain needs to connect to Azure OpenAI
os.environ["OPENAI_API_BASE"] = os.environ["AZURE_OPENAI_ENDPOINT"] = AZURE_OPENAI_ENDPOINT
os.environ["OPENAI_API_KEY"] = os.environ["AZURE_OPENAI_API_KEY"] = AZURE_OPENAI_API_KEY
os.environ["OPENAI_API_VERSION"] = os.environ["AZURE_OPENAI_API_VERSION"] = AZURE_OPENAI_API_VERSION
os.environ["OPENAI_API_TYPE"] = "azure"

# %%
print(os.environ["OPENAI_API_BASE"])
print(os.environ["OPENAI_API_KEY"])
# Out:
# https://cog-42as6n6i4ldsi.openai.azure.com/
# 653103af9cd04492a2232b70327b7ce0

# %%
import pandas as pd
import io
from azure.storage.blob import BlobServiceClient

# Define the connection string and container name
conn_str = "DefaultEndpointsProtocol=https;AccountName=entchatgptstr;AccountKey=gZss7VuVlbiwShlfML34GaeAw3QYEyicbZLF9D47zkGa/GCgx6jNGcNGBz0qqRa4Ci3MPqXrWI2O+AStm9gdMg==;EndpointSuffix=core.windows.net"
container_name = "pubmeddata"

# Create a BlobServiceClient object
blob_service_client = BlobServiceClient.from_connection_string(conn_str)

# Get a reference to the blob container
container_client = blob_service_client.get_container_client(container_name)

# Get a reference to the blob
blob_client = container_client.get_blob_client("df_test_embeddings10k.csv")

# Download the blob as a string
blob_string = blob_client.download_blob().content_as_text(encoding="utf-8")

# Load the string into a Pandas dataframe
df_test = pd.read_csv(io.StringIO(blob_string), encoding="utf-8")

# Print the dataframe
df_test.head()
# Out:
#   Date received                                            Product  \
# 0    2021-09-17  Credit reporting, credit repair services, or o...
# 1    2020-05-26                                    Debt collection
# 2    2022-05-01  Credit reporting, credit repair services, or o...
# 3    2019-10-04  Money transfer, virtual currency, or money ser...
# 4    2022-01-09  Credit reporting, credit repair services, or o...
#
#         Sub-product                                              Issue  \
# 0  Credit reporting  Problem with a credit reporting company's inve...
# 1  Credit card debt  Took or threatened to take negative or legal a...
# 2  Credit reporting                        Improper use of your report
# 3  Virtual currency                                      Fraud or scam
# 4  Credit reporting               Incorrect information on your report
#
#                                            Sub-issue  \
# 0  Their investigation did not fix an error on yo...
# 1     Collected or attempted to collect exempt funds
# 2      Reporting company used your report improperly
# 3                                                NaN
# 4                Information belongs to someone else
#
#                         Consumer complaint narrative  \
# 0  MY NAME IS XXXX XXXX AND I'M SUBMITTING THIS C...
# 1  COLLECTION AGENCIES DEMAND PAYMENT ON ACCOUNTS...
# 2  In accordance with the Fair Credit Reporting a...
# 3  On Friday XX/XX/XXXX I searched in the web XXX...
# 4  Dear Sir or Madam, I checked my personal credi...
#
#                              Company public response  \
# 0  Company has responded to the consumer and the ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Company has responded to the consumer and the ...
#
#                                Company State ZIP code Tags  \
# 0  Experian Information Solutions Inc.    CA    93727  NaN
# 1      Resurgent Capital Services L.P.    CA    90018  NaN
# 2                        EQUIFAX, INC.    AZ    85041  NaN
# 3                 JPMORGAN CHASE & CO.    TX    75043  NaN
# 4  Experian Information Solutions Inc.    NY    10305  NaN
#
#   Consumer consent provided? Submitted via Date sent to company  \
# 0           Consent provided           Web           2021-09-17
# 1           Consent provided           Web           2020-05-26
# 2           Consent provided           Web           2022-05-01
# 3           Consent provided           Web           2019-10-04
# 4           Consent provided           Web           2022-01-09
#
#       Company response to consumer Timely response? Consumer disputed?  \
# 0  Closed with non-monetary relief              Yes                NaN
# 1          Closed with explanation              Yes                NaN
# 2          Closed with explanation              Yes                NaN
# 3          Closed with explanation              Yes                NaN
# 4          Closed with explanation              Yes                NaN
#
#    Complaint ID                               Embeddings_complaint
# 0       4729991  [-0.0461684875190258, -0.018764231353998184, 0...
# 1       3668941  [-0.02608240209519863, -0.027123533189296722, ...
# 2       5523897  [-0.02903948351740837, -0.004012380726635456, ...
# 3       3395771  [-0.01851532608270645, 0.00250532990321517, 0....
# 4       5087511  [-0.028908617794513702, -0.008078554645180702,...

# %%
df_samples = df_test.sample(1000)
# upload to blob
#Safe df_train and df_test to azure blob storage


# Define the connection string and container name
conn_str = "DefaultEndpointsProtocol=https;AccountName=entchatgptstr;AccountKey=gZss7VuVlbiwShlfML34GaeAw3QYEyicbZLF9D47zkGa/GCgx6jNGcNGBz0qqRa4Ci3MPqXrWI2O+AStm9gdMg==;EndpointSuffix=core.windows.net"
container_name = "pubmeddata"

# Create a BlobServiceClient object
blob_service_client = BlobServiceClient.from_connection_string(conn_str)

# Get a reference to the blob container
container_client = blob_service_client.get_container_client(container_name)

# Get a reference to the blob
#blob_client = container_client.get_blob_client("df_train_embeddings10k.csv")

# Upload the blob
#blob_client.upload_blob(df_train.to_csv(index=False), overwrite=True)

# Get a reference to the blob
blob_client = container_client.get_blob_client("df_sample_embeddings10k.csv")

# Upload the blob
blob_client.upload_blob(df_samples.to_csv(index=False), overwrite=True)
# Out:
# {'etag': '"0x8DB836E85D9B62E"',
#  'last_modified': datetime.datetime(2023, 7, 13, 6, 58, 11, tzinfo=datetime.timezone.utc),
#  'content_md5': bytearray(b'B\xb9\x81\x06\xb9n\xdd\x9eI\xc1\x02\xfa\xf9\x89"0'),
#  'client_request_id': 'a1440910-214a-11ee-8840-07237768152c',
#  'request_id': 'a227ed8d-901e-0037-2757-b59ed7000000',
#  'version': '2021-08-06',
#  'version_id': None,
#  'date': datetime.datetime(2023, 7, 13, 6, 58, 10, tzinfo=datetime.timezone.utc),
#  'request_server_encrypted': True,
#  'encryption_key_sha256': None,
#  'encryption_scope': None}

# %%
from langchain.llms import OpenAI
from langchain.chat_models import AzureChatOpenAI
# To help construct our Chat Messages
from langchain.schema import HumanMessage
from langchain.prompts import PromptTemplate, ChatPromptTemplate, HumanMessagePromptTemplate
llm=AzureChatOpenAI(deployment_name="gpt-35-turbo-16k", temperature=0.7)

# I like to use three double quotation marks for my prompts because it's easier to read
prompt = """
You are a financial expert. Give a short and very precise description and an example for a customer complaint for each of the following products in English:
{products}

The output has to be in the following JSON format:
[
    "Product": "Checking or savings account", "description": "A checking account is a deposit account held at a financial institution that allows withdrawals and deposits. Also called demand accounts or transactional accounts, checking accounts are very liquid and can be accessed using checks, automated teller machines, and electronic debits, among other methods.", "example": "example1"
    "Product": "Credit card or prepaid card", "description": "...", "example": "...",
    "Product": "Credit reporting, credit repair services, or other personal consumer reports", "description": "...", "example": "...",
    ...
]
Make sure it is a valid JSON string.
"""
#Extract the distint Products from df_test column Products
products = df_test['Product'].unique().tolist()
print(products)

#Parse the products to the prompt as the following string """-Product1\n-Product2\n-Product3\n...""
products = """-""" + """\n-""".join(products)
#print(products)

prompt = PromptTemplate(
    input_variables= ["products"],
    template=prompt
)
final_prompt = prompt.format(products=products)
print (f"Final Prompt: {final_prompt}")
print ("-----------")
output=llm([HumanMessage(content=final_prompt)])
print(output.content)
# Out:
# ['Credit reporting, credit repair services, or other personal consumer reports', 'Debt collection', 'Money transfer, virtual currency, or money service', 'Mortgage', 'Credit card', 'Student loan', 'Credit reporting', 'Checking or savings account', 'Credit card or prepaid card', 'Payday loan', 'Vehicle loan or lease', 'Payday loan, title loan, or personal loan', 'Prepaid card', 'Bank account or service', 'Consumer Loan', 'Money transfers', 'Other financial service']
# Final Prompt:
# You are a financial expert. Give a short and very precise description and an example for a customer complaint for each of the following products in English:
# -Credit reporting, credit repair services, or other personal consumer reports
# -Debt collection
# -Money transfer, virtual currency, or money service
# -Mortgage
# -Credit card
# -Student loan
# -Credit reporting
# -Checking or savings account
# -Credit card or prepaid card
# -Payday loan
# -Vehicle loan or lease
# -Payday loan, title loan, or personal loan
# -Prepaid card
# -Bank account or service
# -Consumer Loan
# -Money transfers
# -Other financial service
#
# The output has to be in the following JSON format:
# [
#     "Product": "Checking or savings account", "description": "A checking account is a deposit account held at a financial institution that allows withdrawals and deposits. Also called demand accounts or transactional accounts, checking accounts are very liquid and can be accessed using checks, automated teller machines, and electronic debits, among other methods.", "example": "example1"
#     "Product": "Credit card or prepaid card", "description": "...", "example": "...",
#     "Product": "Credit reporting, credit repair services, or other personal consumer reports", "description": "...", "example": "...",
#     ...
# ]
# Make sure it is a valid JSON string.
#
# -----------
# [
#     {
#         "Product": "Credit reporting, credit repair services, or other personal consumer reports",
#         "description": "This product involves credit reports that contain information about an individual's credit history and score. Credit repair services help customers improve their credit report by disputing inaccuracies or errors.",
#         "example": "A customer complains that their credit report contains inaccurate information that is negatively affecting their credit score."
#     },
#     {
#         "Product": "Debt collection",
#         "description": "This product involves collecting debts owed to a creditor. Debt collectors may contact customers to request payment or negotiate payment plans.",
#         "example": "A customer complains that a debt collector is harassing them with frequent phone calls and threatening language."
#     },
#     {
#         "Product": "Money transfer, virtual currency, or money service",
#         "description": "This product involves transferring money between individuals or institutions, often using electronic methods. Virtual currency is a digital form of currency that can be used for transactions.",
#         "example": "A customer complains that their money transfer was delayed or lost, causing them financial hardship."
#     },
#     {
#         "Product": "Mortgage",
#         "description": "This product involves lending money to a customer to purchase a property, with the property serving as collateral for the loan.",
#         "example": "A customer complains that their mortgage lender did not disclose all fees associated with the loan, resulting in unexpected costs."
#     },
#     {
#         "Product": "Credit card",
#         "description": "This product involves providing customers with a line of credit that can be used for purchases. Customers are required to make payments on their balance, often with interest and fees added.",
#         "example": "A customer complains that their credit card company raised their interest rate without proper notification or justification."
#     },
#     {
#         "Product": "Student loan",
#         "description": "This product involves lending money to students to pay for educational expenses. Payments are typically deferred until after graduation, and interest and fees may be added.",
#         "example": "A customer complains that their student loan servicer did not properly process their request for a payment plan, resulting in missed payments and negative credit reporting."
#     },
#     {
#         "Product": "Checking or savings account",
#         "description": "A checking account is a deposit account held at a financial institution that allows withdrawals and deposits. Savings accounts are similar but typically offer higher interest rates and have restrictions on withdrawals.",
#         "example": "A customer complains that their bank charged them multiple overdraft fees for a single transaction, resulting in unexpected charges."
#     },
#     {
#         "Product": "Credit card or prepaid card",
#         "description": "This product involves providing customers with a line of credit or prepaid balance that can be used for purchases. Prepaid cards are typically loaded with a set amount of funds and cannot be overdrawn.",
#         "example": "A customer complains that their prepaid card company charged them multiple fees for inactive usage, resulting in unexpected charges."
#     },
#     {
#         "Product": "Payday loan",
#         "description": "This product involves lending money to customers with the expectation that it will be repaid with their next paycheck. Interest rates and fees on payday loans are often very high.",
#         "example": "A customer complains that their payday lender did not disclose the full cost of the loan, resulting in unexpected charges and financial hardship."
#     },
#     {
#         "Product": "Vehicle loan or lease",
#         "description": "This product involves lending money to a customer to purchase or lease a vehicle, with the vehicle serving as collateral for the loan.",
#         "example": "A customer complains that their vehicle lender did not properly apply their payments, resulting in negative credit reporting and potential repossession of the vehicle."
#     },
#     {
#         "Product": "Payday loan, title loan, or personal loan",
#         "description": "This product involves lending money to customers for personal expenses, with interest rates and fees varying depending on the type of loan and lender.",
#         "example": "A customer complains that their personal loan lender did not properly disclose the interest rate and fees associated with the loan, resulting in unexpected charges."
#     },
#     {
#         "Product": "Prepaid card",
#         "description": "This product involves providing customers with a prepaid balance that can be used for purchases. Prepaid cards are typically loaded with a set amount of funds and cannot be overdrawn.",
#         "example": "A customer complains that their prepaid card company charged them multiple fees for ATM usage, resulting in unexpected charges."
#     },
#     {
#         "Product": "Bank account or service",
#         "description": "This product involves providing customers with various banking services, including checking accounts, savings accounts, and loans.",
#         "example": "A customer complains that their bank did not properly process a deposit, resulting in a delay in funds availability and financial hardship."
#     },
#     {
#         "Product": "Consumer Loan",
#         "description": "This product involves lending money to customers for personal expenses, with interest rates and fees varying depending on the type of loan and lender.",
#         "example": "A customer complains that their loan servicer did not properly apply their payments, resulting in negative credit reporting and potential default on the loan."
#     },
#     {
#         "Product": "Money transfers",
#         "description": "This product involves transferring money between individuals or institutions, often using electronic methods.",
#         "example": "A customer complains that their money transfer was delayed or lost, causing them financial hardship."
#     },
#     {
#         "Product": "Other financial service",
#         "description": "This product encompasses a wide range of financial services, including investment advice, insurance, and financial planning.",
#         "example": "A customer complains that their financial advisor did not properly disclose the risks associated with an investment, resulting in unexpected losses."
#     }
# ]

# %%
print(output.content)
# Out:
# [
#     {
#         "Product": "Credit reporting, credit repair services, or other personal consumer reports",
#         "description": "This product involves credit reports that contain information about an individual's credit history and score. Credit repair services help customers improve their credit report by disputing inaccuracies or errors.",
#         "example": "A customer complains that their credit report contains inaccurate information that is negatively affecting their credit score."
#     },
#     {
#         "Product": "Debt collection",
#         "description": "This product involves collecting debts owed to a creditor. Debt collectors may contact customers to request payment or negotiate payment plans.",
#         "example": "A customer complains that a debt collector is harassing them with frequent phone calls and threatening language."
#     },
#     {
#         "Product": "Money transfer, virtual currency, or money service",
#         "description": "This product involves transferring money between individuals or institutions, often using electronic methods. Virtual currency is a digital form of currency that can be used for transactions.",
#         "example": "A customer complains that their money transfer was delayed or lost, causing them financial hardship."
#     },
#     {
#         "Product": "Mortgage",
#         "description": "This product involves lending money to a customer to purchase a property, with the property serving as collateral for the loan.",
#         "example": "A customer complains that their mortgage lender did not disclose all fees associated with the loan, resulting in unexpected costs."
#     },
#     {
#         "Product": "Credit card",
#         "description": "This product involves providing customers with a line of credit that can be used for purchases. Customers are required to make payments on their balance, often with interest and fees added.",
#         "example": "A customer complains that their credit card company raised their interest rate without proper notification or justification."
#     },
#     {
#         "Product": "Student loan",
#         "description": "This product involves lending money to students to pay for educational expenses. Payments are typically deferred until after graduation, and interest and fees may be added.",
#         "example": "A customer complains that their student loan servicer did not properly process their request for a payment plan, resulting in missed payments and negative credit reporting."
#     },
#     {
#         "Product": "Checking or savings account",
#         "description": "A checking account is a deposit account held at a financial institution that allows withdrawals and deposits. Savings accounts are similar but typically offer higher interest rates and have restrictions on withdrawals.",
#         "example": "A customer complains that their bank charged them multiple overdraft fees for a single transaction, resulting in unexpected charges."
#     },
#     {
#         "Product": "Credit card or prepaid card",
#         "description": "This product involves providing customers with a line of credit or prepaid balance that can be used for purchases. Prepaid cards are typically loaded with a set amount of funds and cannot be overdrawn.",
#         "example": "A customer complains that their prepaid card company charged them multiple fees for inactive usage, resulting in unexpected charges."
#     },
#     {
#         "Product": "Payday loan",
#         "description": "This product involves lending money to customers with the expectation that it will be repaid with their next paycheck. Interest rates and fees on payday loans are often very high.",
#         "example": "A customer complains that their payday lender did not disclose the full cost of the loan, resulting in unexpected charges and financial hardship."
#     },
#     {
#         "Product": "Vehicle loan or lease",
#         "description": "This product involves lending money to a customer to purchase or lease a vehicle, with the vehicle serving as collateral for the loan.",
#         "example": "A customer complains that their vehicle lender did not properly apply their payments, resulting in negative credit reporting and potential repossession of the vehicle."
#     },
#     {
#         "Product": "Payday loan, title loan, or personal loan",
#         "description": "This product involves lending money to customers for personal expenses, with interest rates and fees varying depending on the type of loan and lender.",
#         "example": "A customer complains that their personal loan lender did not properly disclose the interest rate and fees associated with the loan, resulting in unexpected charges."
#     },
#     {
#         "Product": "Prepaid card",
#         "description": "This product involves providing customers with a prepaid balance that can be used for purchases. Prepaid cards are typically loaded with a set amount of funds and cannot be overdrawn.",
#         "example": "A customer complains that their prepaid card company charged them multiple fees for ATM usage, resulting in unexpected charges."
#     },
#     {
#         "Product": "Bank account or service",
#         "description": "This product involves providing customers with various banking services, including checking accounts, savings accounts, and loans.",
#         "example": "A customer complains that their bank did not properly process a deposit, resulting in a delay in funds availability and financial hardship."
#     },
#     {
#         "Product": "Consumer Loan",
#         "description": "This product involves lending money to customers for personal expenses, with interest rates and fees varying depending on the type of loan and lender.",
#         "example": "A customer complains that their loan servicer did not properly apply their payments, resulting in negative credit reporting and potential default on the loan."
#     },
#     {
#         "Product": "Money transfers",
#         "description": "This product involves transferring money between individuals or institutions, often using electronic methods.",
#         "example": "A customer complains that their money transfer was delayed or lost, causing them financial hardship."
#     },
#     {
#         "Product": "Other financial service",
#         "description": "This product encompasses a wide range of financial services, including investment advice, insurance, and financial planning.",
#         "example": "A customer complains that their financial advisor did not properly disclose the risks associated with an investment, resulting in unexpected losses."
#     }
# ]

# %%
import json

# Parse the string into a list of dictionaries
examples = json.loads(output.content)

# Convert the list of dictionaries into the desired format
new_examples = []
for example in examples:
    new_example = {
        "Product": str(example["Product"]),
        "description": str(example["description"]),
        "example": str(example["example"])
    }
    new_examples.append(new_example)

# %%
from langchain.prompts.example_selector import SemanticSimilarityExampleSelector
from langchain.vectorstores import FAISS
from langchain.embeddings import OpenAIEmbeddings
from langchain.prompts import FewShotPromptTemplate, PromptTemplate
#from langchain.llms import AzureChatOpenAI

llm = AzureChatOpenAI(deployment_name="gpt-35-turbo-16k", temperature=0.7)


example_prompt = PromptTemplate(
    input_variables=["Product", "description", "example"],
    template="Product category: {Product}\nDescription: {description}\nCustomer complaint example: {example}\n",
)

# %%
print(llm)
# Out:
# verbose=False callbacks=None callback_manager=None tags=None client=<class 'openai.api_resources.chat_completion.ChatCompletion'> model_name='gpt-3.5-turbo' temperature=0.7 model_kwargs={} openai_api_key='653103af9cd04492a2232b70327b7ce0' openai_api_base='https://cog-42as6n6i4ldsi.openai.azure.com/' openai_organization='' openai_proxy='' request_timeout=None max_retries=6 streaming=False n=1 max_tokens=None deployment_name='gpt-35-turbo-16k' openai_api_type='azure' openai_api_version='2023-03-15-preview'

# %%
# !pip install faiss-cpu
# Out:
# Requirement already satisfied: faiss-cpu in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (1.7.4)

# %%
# SemanticSimilarityExampleSelector will select examples that are similar to your input by semantic meaning

example_selector = SemanticSimilarityExampleSelector.from_examples(
    # This is the list of examples available to select from.
    examples, 
    
    # This is the embedding class used to produce embeddings which are used to measure semantic similarity.
    OpenAIEmbeddings(model="text-embedding-ada-002", chunk_size=1), 
        
    # This is the VectorStore class that is used to store the embeddings and do a similarity search over.
    FAISS, 
    
    # This is the number of examples to produce.
    k=5
)

# %%
similar_prompt = FewShotPromptTemplate(
    # The object that will help select examples
    example_selector=example_selector,
    
    # Your prompt
    example_prompt=example_prompt,
    
    # Customizations that will be added to the top and bottom of your prompt
    prefix="You are a financial expert and your task is to classify a customer complaint into a Product Category. You are given a customer complaint:\n{customer_complaint}\nYou have 5 examples of the Product categories, description and an example:",
    suffix="Classify the customer complaint into one Product Category. ONLY return the result of the Product Category:",
    
    # What inputs your prompt will receive
    input_variables=["customer_complaint"],
)

# %%
# Select a noun!
customer_complaint = "In accordance with the Fair Credit Reporting Act. The List of accounts below has violated my federally protected consumer rights to privacy and confidentiality under 15 USC 1681. Account Name : XXXX XXXX XXXX  Account # XXXX, Account Name : XXXX XXXX Account # XXXX has violated my rights. 15 U.S.C 1681 section 602 A. States I have the right to privacy. 15 U.S.C 1681 Section 604 A Section 2 : It also states a consumer reporting agency can not furnish an account without my written instructions 15 U.S.C 1681c. ( a ) ( 5 ) Section States : no consumer reporting agency may make any consumer report containing any of the following items of information or any other adverse item of information, other than records of convictions of crimes which antedates the report by more than seven years. 15 U.S.C. 1681s-2 ( A ) ( 1 ) A person shall not furnish any information relating to a consumer to any consumer reporting agency if the person knows or has reasonable cause to believe that the information is inaccurate."

# Generate the prompt
print(similar_prompt.format(customer_complaint=customer_complaint))
# Out:
# You are a financial expert and your task is to classify a customer complaint into a Product Category. You are given a customer complaint:
# In accordance with the Fair Credit Reporting Act. The List of accounts below has violated my federally protected consumer rights to privacy and confidentiality under 15 USC 1681. Account Name : XXXX XXXX XXXX  Account # XXXX, Account Name : XXXX XXXX Account # XXXX has violated my rights. 15 U.S.C 1681 section 602 A. States I have the right to privacy. 15 U.S.C 1681 Section 604 A Section 2 : It also states a consumer reporting agency can not furnish an account without my written instructions 15 U.S.C 1681c. ( a ) ( 5 ) Section States : no consumer reporting agency may make any consumer report containing any of the following items of information or any other adverse item of information, other than records of convictions of crimes which antedates the report by more than seven years. 15 U.S.C. 1681s-2 ( A ) ( 1 ) A person shall not furnish any information relating to a consumer to any consumer reporting agency if the person knows or has reasonable cause to believe that the information is inaccurate.
# You have 5 examples of the Product categories, description and an example:
#
# Product category: Credit reporting, credit repair services, or other personal consumer reports
# Description: This product involves credit reports that contain information about an individual's credit history and score. Credit repair services help customers improve their credit report by disputing inaccuracies or errors.
# Customer complaint example: A customer complains that their credit report contains inaccurate information that is negatively affecting their credit score.
#
#
# Product category: Consumer Loan
# Description: This product involves lending money to customers for personal expenses, with interest rates and fees varying depending on the type of loan and lender.
# Customer complaint example: A customer complains that their loan servicer did not properly apply their payments, resulting in negative credit reporting and potential default on the loan.
#
#
# Product category: Credit card
# Description: This product involves providing customers with a line of credit that can be used for purchases. Customers are required to make payments on their balance, often with interest and fees added.
# Customer complaint example: A customer complains that their credit card company raised their interest rate without proper notification or justification.
#
#
# Product category: Vehicle loan or lease
# Description: This product involves lending money to a customer to purchase or lease a vehicle, with the vehicle serving as collateral for the loan.
# Customer complaint example: A customer complains that their vehicle lender did not properly apply their payments, resulting in negative credit reporting and potential repossession of the vehicle.
#
#
# Product category: Bank account or service
# Description: This product involves providing customers with various banking services, including checking accounts, savings accounts, and loans.
# Customer complaint example: A customer complains that their bank did not properly process a deposit, resulting in a delay in funds availability and financial hardship.
#
#
# Classify the customer complaint into one Product Category. ONLY return the result of the Product Category:

# %%
print(len(df_test))

df_test_2=df_test.head(200)
# Out:
# 10000

# %%
formatted_prompt = similar_prompt.format(customer_complaint=customer_complaint)  
print("Formatted Prompt:", formatted_prompt)  
  
human_msg = HumanMessage(content=formatted_prompt)  
completion_response = llm([human_msg])
# Out:
# Formatted Prompt: You are a financial expert and your task is to classify a customer complaint into a Product Category. You are given a customer complaint:
# In accordance with the Fair Credit Reporting Act. The List of accounts below has violated my federally protected consumer rights to privacy and confidentiality under 15 USC 1681. Account Name : XXXX XXXX XXXX  Account # XXXX, Account Name : XXXX XXXX Account # XXXX has violated my rights. 15 U.S.C 1681 section 602 A. States I have the right to privacy. 15 U.S.C 1681 Section 604 A Section 2 : It also states a consumer reporting agency can not furnish an account without my written instructions 15 U.S.C 1681c. ( a ) ( 5 ) Section States : no consumer reporting agency may make any consumer report containing any of the following items of information or any other adverse item of information, other than records of convictions of crimes which antedates the report by more than seven years. 15 U.S.C. 1681s-2 ( A ) ( 1 ) A person shall not furnish any information relating to a consumer to any consumer reporting agency if the person knows or has reasonable cause to believe that the information is inaccurate.
# You have 5 examples of the Product categories, description and an example:
#
# Product category: Credit reporting, credit repair services, or other personal consumer reports
# Description: This product involves credit reports that contain information about an individual's credit history and score. Credit repair services help customers improve their credit report by disputing inaccuracies or errors.
# Customer complaint example: A customer complains that their credit report contains inaccurate information that is negatively affecting their credit score.
#
#
# Product category: Consumer Loan
# Description: This product involves lending money to customers for personal expenses, with interest rates and fees varying depending on the type of loan and lender.
# Customer complaint example: A customer complains that their loan servicer did not properly apply their payments, resulting in negative credit reporting and potential default on the loan.
#
#
# Product category: Credit card
# Description: This product involves providing customers with a line of credit that can be used for purchases. Customers are required to make payments on their balance, often with interest and fees added.
# Customer complaint example: A customer complains that their credit card company raised their interest rate without proper notification or justification.
#
#
# Product category: Vehicle loan or lease
# Description: This product involves lending money to a customer to purchase or lease a vehicle, with the vehicle serving as collateral for the loan.
# Customer complaint example: A customer complains that their vehicle lender did not properly apply their payments, resulting in negative credit reporting and potential repossession of the vehicle.
#
#
# Product category: Bank account or service
# Description: This product involves providing customers with various banking services, including checking accounts, savings accounts, and loans.
# Customer complaint example: A customer complains that their bank did not properly process a deposit, resulting in a delay in funds availability and financial hardship.
#
#
# Classify the customer complaint into one Product Category. ONLY return the result of the Product Category:
# Retrying langchain.chat_models.openai.ChatOpenAI.completion_with_retry.<locals>._completion_with_retry in 1.0 seconds as it raised Timeout: Request timed out: HTTPSConnectionPool(host='cog-42as6n6i4ldsi.openai.azure.com', port=443): Read timed out. (read timeout=600).

# %%
formatted_prompt = similar_prompt.format(customer_complaint=customer_complaint)  
print("Formatted Prompt:", formatted_prompt)  
  
human_msg = HumanMessage(content=formatted_prompt)  
completion_response = llm([human_msg])  

print(completion_response.content)
#output=llm([HumanMessage(content=final_prompt)])
# Out:
# Formatted Prompt: You are a financial expert and your task is to classify a customer complaint into a Product Category. You are given a customer complaint:
# In accordance with the Fair Credit Reporting Act. The List of accounts below has violated my federally protected consumer rights to privacy and confidentiality under 15 USC 1681. Account Name : XXXX XXXX XXXX  Account # XXXX, Account Name : XXXX XXXX Account # XXXX has violated my rights. 15 U.S.C 1681 section 602 A. States I have the right to privacy. 15 U.S.C 1681 Section 604 A Section 2 : It also states a consumer reporting agency can not furnish an account without my written instructions 15 U.S.C 1681c. ( a ) ( 5 ) Section States : no consumer reporting agency may make any consumer report containing any of the following items of information or any other adverse item of information, other than records of convictions of crimes which antedates the report by more than seven years. 15 U.S.C. 1681s-2 ( A ) ( 1 ) A person shall not furnish any information relating to a consumer to any consumer reporting agency if the person knows or has reasonable cause to believe that the information is inaccurate.
# You have 5 examples of the Product categories, description and an example:
#
# Product category: Credit reporting, credit repair services, or other personal consumer reports
# Description: This product involves credit reports that contain information about an individual's credit history and score. Credit repair services help customers improve their credit report by disputing inaccuracies or errors.
# Customer complaint example: A customer complains that their credit report contains inaccurate information that is negatively affecting their credit score.
#
#
# Product category: Consumer Loan
# Description: This product involves lending money to customers for personal expenses, with interest rates and fees varying depending on the type of loan and lender.
# Customer complaint example: A customer complains that their loan servicer did not properly apply their payments, resulting in negative credit reporting and potential default on the loan.
#
#
# Product category: Credit card
# Description: This product involves providing customers with a line of credit that can be used for purchases. Customers are required to make payments on their balance, often with interest and fees added.
# Customer complaint example: A customer complains that their credit card company raised their interest rate without proper notification or justification.
#
#
# Product category: Vehicle loan or lease
# Description: This product involves lending money to a customer to purchase or lease a vehicle, with the vehicle serving as collateral for the loan.
# Customer complaint example: A customer complains that their vehicle lender did not properly apply their payments, resulting in negative credit reporting and potential repossession of the vehicle.
#
#
# Product category: Bank account or service
# Description: This product involves providing customers with various banking services, including checking accounts, savings accounts, and loans.
# Customer complaint example: A customer complains that their bank did not properly process a deposit, resulting in a delay in funds availability and financial hardship.
#
#
# Classify the customer complaint into one Product Category. ONLY return the result of the Product Category:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 5
#       2 print("Formatted Prompt:", formatted_prompt)
#       4 human_msg = HumanMessage(content=formatted_prompt)
# ----> 5 completion_response = llm([human_msg])
#       7 print(completion_response.content)
#       8 #output=llm([HumanMessage(content=final_prompt)])
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/langchain/chat_models/base.py:208, in BaseChatModel.__call__(self, messages, stop, callbacks, **kwargs)
#     201 def __call__(
#     202     self,
#     203     messages: List[BaseMessage],
#    (...)
#     206     **kwargs: Any,
#     207 ) -> BaseMessage:
# --> 208     generation = self.generate(
#     209         [messages], stop=stop, callbacks=callbacks, **kwargs
#     210     ).generations[0][0]
#     211     if isinstance(generation, ChatGeneration):
#     212         return generation.message
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/langchain/chat_models/base.py:102, in BaseChatModel.generate(self, messages, stop, callbacks, tags, **kwargs)
#     100 except (KeyboardInterrupt, Exception) as e:
#     101     run_manager.on_llm_error(e)
# --> 102     raise e
#     103 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#     104 generations = [res.generations for res in results]
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/langchain/chat_models/base.py:94, in BaseChatModel.generate(self, messages, stop, callbacks, tags, **kwargs)
#      90 new_arg_supported = inspect.signature(self._generate).parameters.get(
#      91     "run_manager"
#      92 )
#      93 try:
# ---> 94     results = [
#      95         self._generate(m, stop=stop, run_manager=run_manager, **kwargs)
#      96         if new_arg_supported
#      97         else self._generate(m, stop=stop)
#      98         for m in messages
#      99     ]
#     100 except (KeyboardInterrupt, Exception) as e:
#     101     run_manager.on_llm_error(e)
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/langchain/chat_models/base.py:95, in <listcomp>(.0)
#      90 new_arg_supported = inspect.signature(self._generate).parameters.get(
#      91     "run_manager"
#      92 )
#      93 try:
#      94     results = [
# ---> 95         self._generate(m, stop=stop, run_manager=run_manager, **kwargs)
#      96         if new_arg_supported
#      97         else self._generate(m, stop=stop)
#      98         for m in messages
#      99     ]
#     100 except (KeyboardInterrupt, Exception) as e:
#     101     run_manager.on_llm_error(e)
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/langchain/chat_models/openai.py:359, in ChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#     351     message = _convert_dict_to_message(
#     352         {
#     353             "content": inner_completion,
#    (...)
#     356         }
#     357     )
#     358     return ChatResult(generations=[ChatGeneration(message=message)])
# --> 359 response = self.completion_with_retry(messages=message_dicts, **params)
#     360 return self._create_chat_result(response)
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/langchain/chat_models/openai.py:307, in ChatOpenAI.completion_with_retry(self, **kwargs)
#     303 @retry_decorator
#     304 def _completion_with_retry(**kwargs: Any) -> Any:
#     305     return self.client.create(**kwargs)
# --> 307 return _completion_with_retry(**kwargs)
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/tenacity/__init__.py:289, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     287 @functools.wraps(f)
#     288 def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 289     return self(f, *args, **kw)
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/tenacity/__init__.py:379, in Retrying.__call__(self, fn, *args, **kwargs)
#     377 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     378 while True:
# --> 379     do = self.iter(retry_state=retry_state)
#     380     if isinstance(do, DoAttempt):
#     381         try:
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/tenacity/__init__.py:314, in BaseRetrying.iter(self, retry_state)
#     312 is_explicit_retry = fut.failed and isinstance(fut.exception(), TryAgain)
#     313 if not (is_explicit_retry or self.retry(retry_state)):
# --> 314     return fut.result()
#     316 if self.after is not None:
#     317     self.after(retry_state)
#
# File /anaconda/envs/azureml_py38/lib/python3.8/concurrent/futures/_base.py:432, in Future.result(self, timeout)
#     430     raise CancelledError()
#     431 elif self._state == FINISHED:
# --> 432     return self.__get_result()
#     434 self._condition.wait(timeout)
#     436 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /anaconda/envs/azureml_py38/lib/python3.8/concurrent/futures/_base.py:388, in Future.__get_result(self)
#     386 def __get_result(self):
#     387     if self._exception:
# --> 388         raise self._exception
#     389     else:
#     390         return self._result
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/tenacity/__init__.py:382, in Retrying.__call__(self, fn, *args, **kwargs)
#     380 if isinstance(do, DoAttempt):
#     381     try:
# --> 382         result = fn(*args, **kwargs)
#     383     except BaseException:  # noqa: B902
#     384         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/langchain/chat_models/openai.py:305, in ChatOpenAI.completion_with_retry.<locals>._completion_with_retry(**kwargs)
#     303 @retry_decorator
#     304 def _completion_with_retry(**kwargs: Any) -> Any:
# --> 305     return self.client.create(**kwargs)
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/openai/api_resources/chat_completion.py:25, in ChatCompletion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
#      27         if timeout is not None and time.time() > start + timeout:
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/openai/api_resources/abstract/engine_api_resource.py:153, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     127 @classmethod
#     128 def create(
#     129     cls,
#    (...)
#     136     **params,
#     137 ):
#     138     (
#     139         deployment_id,
#     140         engine,
#    (...)
#     150         api_key, api_base, api_type, api_version, organization, **params
#     151     )
# --> 153     response, _, api_key = requestor.request(
#     154         "post",
#     155         url,
#     156         params=params,
#     157         headers=headers,
#     158         stream=stream,
#     159         request_id=request_id,
#     160         request_timeout=request_timeout,
#     161     )
#     163     if stream:
#     164         # must be an iterator
#     165         assert not isinstance(response, OpenAIResponse)
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/openai/api_requestor.py:288, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     277 def request(
#     278     self,
#     279     method,
#    (...)
#     286     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     287 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
# --> 288     result = self.request_raw(
#     289         method.lower(),
#     290         url,
#     291         params=params,
#     292         supplied_headers=headers,
#     293         files=files,
#     294         stream=stream,
#     295         request_id=request_id,
#     296         request_timeout=request_timeout,
#     297     )
#     298     resp, got_stream = self._interpret_response(result, stream)
#     299     return resp, got_stream, self.api_key
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/openai/api_requestor.py:596, in APIRequestor.request_raw(self, method, url, params, supplied_headers, files, stream, request_id, request_timeout)
#     594     _thread_context.session_create_time = time.time()
#     595 try:
# --> 596     result = _thread_context.session.request(
#     597         method,
#     598         abs_url,
#     599         headers=headers,
#     600         data=data,
#     601         files=files,
#     602         stream=stream,
#     603         timeout=request_timeout if request_timeout else TIMEOUT_SECS,
#     604         proxies=_thread_context.session.proxies,
#     605     )
#     606 except requests.exceptions.Timeout as e:
#     607     raise error.Timeout("Request timed out: {}".format(e)) from e
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File /anaconda/envs/azureml_py38/lib/python3.8/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File /anaconda/envs/azureml_py38/lib/python3.8/http/client.py:1347, in HTTPConnection.getresponse(self)
#    1345 try:
#    1346     try:
# -> 1347         response.begin()
#    1348     except ConnectionError:
#    1349         self.close()
#
# File /anaconda/envs/azureml_py38/lib/python3.8/http/client.py:307, in HTTPResponse.begin(self)
#     305 # read until we get a non-100 response
#     306 while True:
# --> 307     version, status, reason = self._read_status()
#     308     if status != CONTINUE:
#     309         break
#
# File /anaconda/envs/azureml_py38/lib/python3.8/http/client.py:268, in HTTPResponse._read_status(self)
#     267 def _read_status(self):
# --> 268     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269     if len(line) > _MAXLINE:
#     270         raise LineTooLong("status line")
#
# File /anaconda/envs/azureml_py38/lib/python3.8/socket.py:669, in SocketIO.readinto(self, b)
#     667 while True:
#     668     try:
# --> 669         return self._sock.recv_into(b)
#     670     except timeout:
#     671         self._timeout_occurred = True
#
# File /anaconda/envs/azureml_py38/lib/python3.8/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File /anaconda/envs/azureml_py38/lib/python3.8/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# Use the llm function and feed in the column customer complaint from df

def get_prediction(customer_complaint):  
    formatted_prompt = similar_prompt.format(customer_complaint=customer_complaint)  
    human_msg = HumanMessage(content=formatted_prompt)  
    completion_response = llm([human_msg])  
  
    # Assuming the response is in the 'content' attribute, extract the content  
    prediction = completion_response.content  
    return prediction  
  
df_test_2["prediction"] = df_test_2["Consumer complaint narrative"].apply(get_prediction)  


#clean any new lines from the predictions
df_test_2["prediction"] = df_test_2["prediction"].apply(lambda x: x.replace("\n", ""))
# Out:
# Retrying langchain.chat_models.openai.ChatOpenAI.completion_with_retry.<locals>._completion_with_retry in 1.0 seconds as it raised Timeout: Request timed out: HTTPSConnectionPool(host='cog-42as6n6i4ldsi.openai.azure.com', port=443): Read timed out. (read timeout=600).
# Retrying langchain.chat_models.openai.ChatOpenAI.completion_with_retry.<locals>._completion_with_retry in 1.0 seconds as it raised Timeout: Request timed out: HTTPSConnectionPool(host='cog-42as6n6i4ldsi.openai.azure.com', port=443): Read timed out. (read timeout=600).
# Retrying langchain.chat_models.openai.ChatOpenAI.completion_with_retry.<locals>._completion_with_retry in 1.0 seconds as it raised Timeout: Request timed out: HTTPSConnectionPool(host='cog-42as6n6i4ldsi.openai.azure.com', port=443): Read timed out. (read timeout=600).
# Retrying langchain.chat_models.openai.ChatOpenAI.completion_with_retry.<locals>._completion_with_retry in 1.0 seconds as it raised Timeout: Request timed out: HTTPSConnectionPool(host='cog-42as6n6i4ldsi.openai.azure.com', port=443): Read timed out. (read timeout=600).
# Retrying langchain.chat_models.openai.ChatOpenAI.completion_with_retry.<locals>._completion_with_retry in 1.0 seconds as it raised Timeout: Request timed out: HTTPSConnectionPool(host='cog-42as6n6i4ldsi.openai.azure.com', port=443): Read timed out. (read timeout=600).
# Retrying langchain.chat_models.openai.ChatOpenAI.completion_with_retry.<locals>._completion_with_retry in 1.0 seconds as it raised Timeout: Request timed out: HTTPSConnectionPool(host='cog-42as6n6i4ldsi.openai.azure.com', port=443): Read timed out. (read timeout=600).
# Retrying langchain.chat_models.openai.ChatOpenAI.completion_with_retry.<locals>._completion_with_retry in 1.0 seconds as it raised Timeout: Request timed out: HTTPSConnectionPool(host='cog-42as6n6i4ldsi.openai.azure.com', port=443): Read timed out. (read timeout=600).
# Retrying langchain.chat_models.openai.ChatOpenAI.completion_with_retry.<locals>._completion_with_retry in 1.0 seconds as it raised Timeout: Request timed out: HTTPSConnectionPool(host='cog-42as6n6i4ldsi.openai.azure.com', port=443): Read timed out. (read timeout=600).
# Retrying langchain.chat_models.openai.ChatOpenAI.completion_with_retry.<locals>._completion_with_retry in 1.0 seconds as it raised Timeout: Request timed out: HTTPSConnectionPool(host='cog-42as6n6i4ldsi.openai.azure.com', port=443): Read timed out. (read timeout=600).
# Retrying langchain.chat_models.openai.ChatOpenAI.completion_with_retry.<locals>._completion_with_retry in 1.0 seconds as it raised Timeout: Request timed out: HTTPSConnectionPool(host='cog-42as6n6i4ldsi.openai.azure.com', port=443): Read timed out. (read timeout=600).
# /tmp/ipykernel_101120/2789392241.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test_2["prediction"] = df_test_2["Consumer complaint narrative"].apply(get_prediction)
# /tmp/ipykernel_101120/2789392241.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test_2["prediction"] = df_test_2["prediction"].apply(lambda x: x.replace("\n", ""))

# %%
df_test_2.head()
#count df_test rows by prediction
len(df_test_2["prediction"].value_counts())
df_test_2.head()
# Out:
#   Date received                                            Product  \
# 0    2021-09-17  Credit reporting, credit repair services, or o...
# 1    2020-05-26                                    Debt collection
# 2    2022-05-01  Credit reporting, credit repair services, or o...
# 3    2019-10-04  Money transfer, virtual currency, or money ser...
# 4    2022-01-09  Credit reporting, credit repair services, or o...
#
#         Sub-product                                              Issue  \
# 0  Credit reporting  Problem with a credit reporting company's inve...
# 1  Credit card debt  Took or threatened to take negative or legal a...
# 2  Credit reporting                        Improper use of your report
# 3  Virtual currency                                      Fraud or scam
# 4  Credit reporting               Incorrect information on your report
#
#                                            Sub-issue  \
# 0  Their investigation did not fix an error on yo...
# 1     Collected or attempted to collect exempt funds
# 2      Reporting company used your report improperly
# 3                                                NaN
# 4                Information belongs to someone else
#
#                         Consumer complaint narrative  \
# 0  MY NAME IS XXXX XXXX AND I'M SUBMITTING THIS C...
# 1  COLLECTION AGENCIES DEMAND PAYMENT ON ACCOUNTS...
# 2  In accordance with the Fair Credit Reporting a...
# 3  On Friday XX/XX/XXXX I searched in the web XXX...
# 4  Dear Sir or Madam, I checked my personal credi...
#
#                              Company public response  \
# 0  Company has responded to the consumer and the ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Company has responded to the consumer and the ...
#
#                                Company State ZIP code Tags  \
# 0  Experian Information Solutions Inc.    CA    93727  NaN
# 1      Resurgent Capital Services L.P.    CA    90018  NaN
# 2                        EQUIFAX, INC.    AZ    85041  NaN
# 3                 JPMORGAN CHASE & CO.    TX    75043  NaN
# 4  Experian Information Solutions Inc.    NY    10305  NaN
#
#   Consumer consent provided? Submitted via Date sent to company  \
# 0           Consent provided           Web           2021-09-17
# 1           Consent provided           Web           2020-05-26
# 2           Consent provided           Web           2022-05-01
# 3           Consent provided           Web           2019-10-04
# 4           Consent provided           Web           2022-01-09
#
#       Company response to consumer Timely response? Consumer disputed?  \
# 0  Closed with non-monetary relief              Yes                NaN
# 1          Closed with explanation              Yes                NaN
# 2          Closed with explanation              Yes                NaN
# 3          Closed with explanation              Yes                NaN
# 4          Closed with explanation              Yes                NaN
#
#    Complaint ID                               Embeddings_complaint  \
# 0       4729991  [-0.0461684875190258, -0.018764231353998184, 0...
# 1       3668941  [-0.02608240209519863, -0.027123533189296722, ...
# 2       5523897  [-0.02903948351740837, -0.004012380726635456, ...
# 3       3395771  [-0.01851532608270645, 0.00250532990321517, 0....
# 4       5087511  [-0.028908617794513702, -0.008078554645180702,...
#
#                                           prediction
# 0                                           Mortgage
# 1                                    Debt collection
# 2  Credit reporting, credit repair services, or o...
# 3            Product category: Vehicle loan or lease
# 4  Credit reporting, credit repair services, or o...

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score  
  
# Assuming you have already loaded the dataframe 'df' with the relevant data  
  
# Extract the ground truth labels (actual products) and the predicted labels  
y_true = df_test_2['Product']  
y_pred = df_test_2['prediction']  
  
# Calculate evaluation metrics  
accuracy = accuracy_score(y_true, y_pred)  
precision = precision_score(y_true, y_pred, average='weighted')  
recall = recall_score(y_true, y_pred, average='weighted')  
f1 = f1_score(y_true, y_pred, average='weighted')  
  
# Print the evaluation results  
print("Accuracy:", accuracy)  
print("Precision:", precision)  
print("Recall:", recall)  
print("F1-score:", f1)
# Out:
# Accuracy: 0.315
# Precision: 0.7068745346794126
# Recall: 0.315
# F1-score: 0.4132270264770266
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.metrics import classification_report  
  
# Assuming you have already loaded the dataframe 'df' with the relevant data  
  
# Extract the ground truth labels (actual products) and the predicted labels  
y_true = df_test_2['Product']  
y_pred = df_test_2['prediction']  
  
# Generate a classification report  
report = classification_report(y_true, y_pred)  
  
# Print the classification report  
print(report)
# Out:
#                                                                                                  precision    recall  f1-score   support
#
#                                                                         Bank account or service       0.08      0.50      0.13         2
#                                                                     Checking or savings account       0.00      0.00      0.00        11
#                                                                    Checking or savings account.       0.00      0.00      0.00         0
#                                                                                   Consumer Loan       0.00      0.00      0.00         0
#                                                                                     Credit card       0.22      0.50      0.31         4
#                                                                     Credit card or prepaid card       0.50      0.07      0.12        14
#                                                                    Credit card or prepaid card.       0.00      0.00      0.00         0
#                                                                                    Credit card.       0.00      0.00      0.00         0
#                                                                                Credit reporting       0.00      0.00      0.00         4
#                    Credit reporting, credit repair services, or other personal consumer reports       0.88      0.34      0.49       107
#                   Credit reporting, credit repair services, or other personal consumer reports.       0.00      0.00      0.00         0
#                                                                                 Debt collection       0.71      0.22      0.33        23
#                                                                                Debt collection.       0.00      0.00      0.00         0
#                                            Money transfer or virtual currency or money service.       0.00      0.00      0.00         0
#                                              Money transfer, virtual currency, or money service       0.00      0.00      0.00         5
#                                                                                        Mortgage       0.71      0.77      0.74        13
#                                                                                   Mortgage loan       0.00      0.00      0.00         0
#                                                                         Other financial service       0.00      0.00      0.00         0
#                                                                        Other financial service.       0.00      0.00      0.00         0
#                                                                                     Payday loan       1.00      0.50      0.67         2
#                                                       Payday loan, title loan, or personal loan       0.00      0.00      0.00         1
#                                                                                    Prepaid card       0.00      0.00      0.00         1
#                                                                  Product Category: Student loan       0.00      0.00      0.00         0
#                                                       Product category: Bank account or service       0.00      0.00      0.00         0
#                                                                  Product category: Credit card.       0.00      0.00      0.00         0
#  Product category: Credit reporting, credit repair services, or other personal consumer reports       0.00      0.00      0.00         0
# Product category: Credit reporting, credit repair services, or other personal consumer reports.       0.00      0.00      0.00         0
#                            Product category: Money transfer, virtual currency, or money service       0.00      0.00      0.00         0
#                                                              Product category: Money transfers.       0.00      0.00      0.00         0
#                                                                      Product category: Mortgage       0.00      0.00      0.00         0
#                                                                  Product category: Payday loan.       0.00      0.00      0.00         0
#                                                                  Product category: Prepaid card       0.00      0.00      0.00         0
#                                                         Product category: Vehicle loan or lease       0.00      0.00      0.00         0
#                                                                                    Student loan       1.00      0.56      0.71         9
#                                                                                   Student loan.       0.00      0.00      0.00         0
#                                                                           Vehicle loan or lease       0.67      0.50      0.57         4
#
#                                                                                        accuracy                           0.32       200
#                                                                                       macro avg       0.16      0.11      0.11       200
#                                                                                    weighted avg       0.71      0.32      0.41       200
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /anaconda/envs/azureml_py38/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
len(df_test_2)
# Out:
# 2

# %%
# count df['prediction'] by row
df_test_2['prediction'].value_counts()
# Out:
# Debt collection.              1
# Product category: Mortgage    1
# Name: prediction, dtype: int64
